# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import datetime as datetime

from weight_lifting import *

# %%
w = WorkoutData()

# %%
w.create_new_workout()

# %%
w.get_weight_lifting_data()
# Out:
#                             Movement Name  Set Number  Weight  Reps     Date  \
# 0             Seated Chest Supported Rows           0    35.0     5  28:14.9
# 1             Seated Chest Supported Rows           1    40.0     5  28:14.9
# 2             Seated Chest Supported Rows           2    45.0     5  28:14.9
# 3             Seated Chest Supported Rows           3    55.0     5  28:14.9
# 4             Seated Chest Supported Rows           4    65.0     5  28:14.9
# 5   Seated Chest Supported Lat Pull Downs           0    45.0     5  28:14.9
# 6   Seated Chest Supported Lat Pull Downs           1    70.0     5  28:14.9
# 7   Seated Chest Supported Lat Pull Downs           2    75.0     3  28:14.9
# 8   Seated Chest Supported Lat Pull Downs           3    70.0     2  28:14.9
# 9   Seated Chest Supported Lat Pull Downs           4    55.0     5  28:14.9
# 10                             Face Pulls           0    22.5    10  28:14.9
# ...

# %%
workout_plan = w.get_workout_plan()

# %%
workout_plan['Workout Name'].unique()
# Out:
# array(['Back1', 'Legs1', 'Upper1', 'Legs2', 'Back2'], dtype=object)

# %%
workout_plan[workout_plan['Workout Name'] == 'Legs2']
# Out:
#    Workout Name        Movement Name  Sets  Reps  Date  Notes
# 13        Legs2  Barbell Back Squats     5     5   NaN    NaN
# 14        Legs2           KOT Lunges     4    10   NaN    NaN
# 15        Legs2      Hamstring Curls     4    10   NaN    NaN

# %%
w.get_weight_lifting_data()
# Out:
#                             Movement Name  Set Number  Weight  Reps     Date  \
# 0             Seated Chest Supported Rows           0    35.0     5  28:14.9
# 1             Seated Chest Supported Rows           1    40.0     5  28:14.9
# 2             Seated Chest Supported Rows           2    45.0     5  28:14.9
# 3             Seated Chest Supported Rows           3    55.0     5  28:14.9
# 4             Seated Chest Supported Rows           4    65.0     5  28:14.9
# 5   Seated Chest Supported Lat Pull Downs           0    45.0     5  28:14.9
# 6   Seated Chest Supported Lat Pull Downs           1    70.0     5  28:14.9
# 7   Seated Chest Supported Lat Pull Downs           2    75.0     3  28:14.9
# 8   Seated Chest Supported Lat Pull Downs           3    70.0     2  28:14.9
# 9   Seated Chest Supported Lat Pull Downs           4    55.0     5  28:14.9
# 10                             Face Pulls           0    22.5    10  28:14.9
# ...

# %%
workout_data = w.get_weight_lifting_data()
w.generate_workout_template('Legs2')

# %%
w.create_new_workout()
